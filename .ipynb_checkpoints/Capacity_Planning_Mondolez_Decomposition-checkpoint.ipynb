# %%
import numpy as np
import scipy
import pandas as pd
from pandas import Series
from matplotlib import pyplot
import math
import random
import sklearn
from sklearn import metrics
import seaborn as sns
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot, autocorrelation_plot

#april = pd.read_csv('/Users/nathalie.willems/Documents/AAAM/machine_learning/infra_prediction/sap_sm37_prediction_april_staging_delayed_joined.csv')
#feb = pd.read_csv('/Users/nathalie.willems/Documents/AAAM/machine_learning/infra_prediction/sap_sm37_prediction_feb_staging_delayed_joined.csv')
cpu = pd.read_csv('/Users/nathalie.willems/Documents/AAAM/machine_learning/infra_prediction/sap_st06_cpu_EAP_feb_june_mondolezprod.csv')
mem = pd.read_csv('/Users/nathalie.willems/Documents/AAAM/machine_learning/infra_prediction/sap_st06_mem_EAP_feb_june_mondolezprod.csv')
mem.head(10)
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#                           _time  avg(Value)
# 0  2018-02-13T00:00:00.000+0000         NaN
# 1  2018-02-13T01:00:00.000+0000   16.000000
# 2  2018-02-13T02:00:00.000+0000   16.000000
# 3  2018-02-13T03:00:00.000+0000   16.166667
# 4  2018-02-13T04:00:00.000+0000   16.000000
# 5  2018-02-13T05:00:00.000+0000   15.333333
# 6  2018-02-13T06:00:00.000+0000   13.666667
# 7  2018-02-13T07:00:00.000+0000   13.833333
# 8  2018-02-13T08:00:00.000+0000   14.500000
# 9  2018-02-13T09:00:00.000+0000   14.000000

# %%
plt.figure(figsize=(16,6))
#ax1=plt.subplot(211)
#ax2=plt.subplot(212)
#ax3=plt.subplot(221)
#ax4=plt.subplot(222)
#fg, axarr = plt.subplots(3,2, figsize=(16,10))
ax1 = plt.subplot(121)
ax2 = plt.subplot(122)
ax=lag_plot(cpu['avg(Value)'], ax=ax1)
ax.set_title('CPU autocorrelation')
axx=lag_plot(mem['avg(Value)'], ax=ax2)
axx.set_title('Mem autocorrelation')
plt.show()

# %%
# CPU

plt.figure(figsize=(16,6))
autocorrelation_plot(cpu['avg(Value)'])
plt.show()

# %%
# Mem

plt.figure(figsize=(16,6))
small=mem.head(48)
autocorrelation_plot(small['avg(Value)'])
plt.show()

# %% [markdown]
# ### ARIMA Model - CPU
#
# Model fitting

# %%
# split into train and test sets
cpu.dropna(inplace=True)
X = cpu['avg(Value)'].values
train, test = X[:len(X)-168], X[len(X)-168:]

# %%
small = cpu['avg(Value)']
train = small.values

# %%
# train autoregression
model = ARIMA(train, order=(24,1,0))
model_fit = model.fit()
# fit model
model_fit = model.fit(disp=0)
#print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot(title='Residuals', legend=False)
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
#                  0
# count  2314.000000
# mean     -0.009838
# std       6.548172
# min     -31.241705
# 25%      -4.163151
# 50%      -0.412855
# 75%       3.860813
# max      29.540589

# %% [markdown]
# Model Prediction/Forecasting

# %%
small = cpu['avg(Value)'].head(168)
size = int(len(small) * 66)
train, test = small[0:size], small[size:len(small)]
history = [x for x in train]

# %%
# split into 2/3 of data
#size = int(len(small) * 0.66)
#train, test = small[0:size], small[size:len(small)]
#history = [x for x in train]
predictions = []
for i in range(len(train)):
    model = ARIMA(history, order=(24,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    #print(output)
    yhat = output[0]
    predictions.append(yhat)
    t = 168 + i
    obs = test[t]
    #history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

test2 = test[len(test):len(test)+10]
    
error = metrics.mean_squared_error(test2, predictions)
#print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test2)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 168
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-bc460382aadd> in <module>()
#      12     predictions.append(yhat)
#      13     t = 168 + i
# ---> 14     obs = test[t]
#      15     #history.append(obs)
#      16     print('predicted=%f, expected=%f' % (yhat, obs))
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2564
#    2565             try:
# -> 2566                 return libts.get_value_box(s, key)
#    2567             except IndexError:
#    2568                 raise
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box()
#
# IndexError: index out of bounds

# %% [markdown]
# ### AR Model - CPU

# %%
# split into train and test sets
cpu.dropna(inplace=True)
#X = small['avg(Value)'].values
train, test = X[:len(small)-24], X[len(X)-24:]

# %%
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
    print('predicted=%f, expected=%f' % (predictions[i], test[i]))
error = metrics.mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot results
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Lag: 13
# Coefficients: [ 2.25822726  1.20904843 -0.41404542  0.02922964  0.12157592 -0.15840321
#   0.19402202 -0.2225287   0.16129058 -0.05698786 -0.07670923  0.13830328
#  -0.13511638  0.07394622]
# predicted=12.670858, expected=3.666667
# predicted=13.456649, expected=2.166667
# predicted=14.065563, expected=3.000000
# predicted=14.753106, expected=2.833333
# predicted=15.048356, expected=3.166667
# predicted=15.383451, expected=2.166667
# predicted=15.674639, expected=1.166667
# predicted=15.792356, expected=2.333333
# predicted=15.988808, expected=3.666667
# predicted=16.127322, expected=5.166667
# predicted=16.205386, expected=5.666667
# predicted=16.348561, expected=2.666667
# predicted=16.439481, expected=3.166667
# predicted=16.399005, expected=3.333333
# predicted=16.392219, expected=3.666667
# predicted=16.361282, expected=5.500000
# predicted=16.358134, expected=6.166667
# predicted=16.376968, expected=7.000000
# predicted=16.382847, expected=14.166667
# predicted=16.392109, expected=16.666667
# predicted=16.415467, expected=16.500000
# predicted=16.422255, expected=16.666667
# predicted=16.438802, expected=23.166667
# predicted=16.458733, expected=28.000000
# Test MSE: 114.703

# %% [markdown]
# ### Rolling model

# %%
# train autoregression
model = AR(train)
model_fit = model.fit()
window = model_fit.k_ar
coef = model_fit.params
# walk forward over time steps in test
history = train[len(train)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
    length = len(history)
    lag = [history[i] for i in range(length-window,length)]
    yhat = coef[0]
    for d in range(window):
        yhat += coef[d+1] * lag[window-d-1]
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = metrics.mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=12.670858, expected=3.666667
# predicted=2.570146, expected=2.166667
# predicted=4.143572, expected=3.000000
# predicted=5.785680, expected=2.833333
# predicted=3.793724, expected=3.166667
# predicted=5.683501, expected=2.166667
# predicted=2.962106, expected=1.166667
# predicted=3.493417, expected=2.333333
# predicted=4.693529, expected=3.666667
# predicted=5.494964, expected=5.166667
# predicted=7.888216, expected=5.666667
# predicted=6.855055, expected=2.666667
# predicted=3.967546, expected=3.166667
# predicted=5.733778, expected=3.333333
# predicted=5.086398, expected=3.666667
# predicted=5.437532, expected=5.500000
# predicted=7.849803, expected=6.166667
# predicted=7.252146, expected=7.000000
# predicted=8.931374, expected=14.166667
# predicted=16.687224, expected=16.666667
# predicted=16.911932, expected=16.500000
# predicted=16.355619, expected=16.666667
# predicted=16.794241, expected=23.166667
# predicted=24.536619, expected=28.000000
# Test MSE: 9.326

# %% [markdown]
# ### ARIMA Model - Mem
#
# Joined Data Set

# %%
# split into train and test sets
mem.dropna(inplace=True)
X = mem['avg(Value)'].values
train, test = X[:len(X)-168], X[len(X)-168:]

# %%
small_mem = mem['avg(Value)'].head(168)
train_mem = small_mem.values

# %%
# train autoregression
model_mem = ARIMA(train_mem, order=(24,1,0))
model_mem_fit = model_mem.fit()
# fit model
model_mem_fit = model_mem.fit(disp=0)
#print(model_mem_fit.summary())
# plot residual errors
residuals_mem = pd.DataFrame(model_mem_fit.resid)
residuals_mem.plot()
pyplot.show()
residuals_mem.plot(kind='kde')
pyplot.show()
print(residuals_mem.describe())
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
#                 0
# count  167.000000
# mean     0.002978
# std      0.881620
# min     -3.931276
# 25%     -0.581950
# 50%     -0.053040
# 75%      0.551430
# max      2.640284

# %% [markdown]
# Prediction

# %%
# split into 2/3 of data
size = int(len(small_mem) * 0.66)
train, test = small[0:size], small[size:len(small)]
history = [x for x in train]
predictions = []
for i in range(len(train)):
    model = ARIMA(history, order=(24,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    #print(output)
    yhat = output[0]
    predictions.append(yhat)
    t = 168 + i
    obs = test[t]
    #history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

test2 = test[len(test):len(test)+10]
    
error = metrics.mean_squared_error(test2, predictions)
#print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test2)
pyplot.plot(predictions, color='red')
pyplot.show()
